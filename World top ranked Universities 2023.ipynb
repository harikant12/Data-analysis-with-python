# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/DELL/Desktop/New folder/2023 QS World University Rankings.csv")
data.head()
# Out:
#    Rank                                   institution location code  \
# 0     1  Massachusetts Institute of Technology (MIT)             US
# 1     2                       University of Cambridge            UK
# 2     3                           Stanford University            US
# 3     4                          University of Oxford            UK
# 4     5                            Harvard University            US
#
#          location  ar score ar rank  er score er rank  fsr score fsr rank  \
# 0   United States     100.0       5     100.0       4      100.0       14
# 1  United Kingdom     100.0       2     100.0       2      100.0       11
# 2   United States     100.0       4     100.0       5      100.0        6
# 3  United Kingdom     100.0       3     100.0       3      100.0        8
# 4   United States     100.0       1     100.0       1       99.4       35
#
#    ...  cpf rank ifr score  ifr rank isr score  isr rank irn score  irn rank  \
# ...

# %%
data.describe()
# Out:
#               Rank     ar score     er score    fsr score    cpf score  \
# count  1422.000000  1422.000000  1421.000000  1420.000000  1417.000000
# mean    711.500000    20.124684    20.657143    29.997113    24.529358
# std     410.640354    22.802706    24.027928    28.172207    27.910952
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%     356.250000     5.400000     4.400000     8.200000     3.100000
# 50%     711.500000    10.800000    10.300000    18.250000    11.100000
# 75%    1066.750000    23.775000    27.000000    43.500000    39.400000
# max    1422.000000   100.000000   100.000000   100.000000   100.000000
#
#          ifr score    isr score    irn score    ger score
# count  1324.000000  1365.000000  1409.000000  1410.000000
# mean     31.659517    26.545348    49.570121    26.186809
# std      34.170817    30.896854    30.205439    26.201036
# min       1.000000     1.000000     1.000000     1.000000
# ...

# %%
print(data.values)
# Out:
# [[1 'Massachusetts Institute of Technology (MIT) ' 'US' ... 100.0 '3'
#   '100']
#  [2 'University of Cambridge' 'UK' ... 100.0 '9' '98.8']
#  [3 'Stanford University' 'US' ... 100.0 '2' '98.5']
#  ...
#  [1420 'Université Mohammed V de Rabat' 'MA' ... nan nan '-']
#  [1421 'University of Craiova' 'RO' ... 8.7 '601+' '-']
#  [1422 'University of Oradea' 'RO' ... 9.7 '601+' '-']]

# %%
data.columns
# Out:
# Index(['Rank', 'institution', 'location code', 'location', 'ar score',
#        'ar rank', 'er score', 'er rank', 'fsr score', 'fsr rank', 'cpf score',
#        'cpf rank', 'ifr score', 'ifr rank', 'isr score', 'isr rank',
#        'irn score', 'irn rank', 'ger score', 'ger rank', 'score scaled'],
#       dtype='object')

# %%
data.sort_values("institution", ascending=False)
# Out:
#       Rank                               institution location code  \
# 1259  1260                          Óbuda University            HU
# 110    111          École Normale Supérieure de Lyon            FR
# 1008  1009                      Zhengzhou University            CN
# 42      43                       Zhejiang University            CN
# 754    755                          Zayed University            AE
# ...    ...                                       ...           ...
# 329    330                        Aalborg University            DK
# 805    806  AGH University of Science and Technology            PL
# 500    501                 Western Sydney University            AU
# 353    354                      University of Dundee            UK
# 1204  1205            Don State Technical University            RU
#
#                   location  ar score ar rank  er score er rank  fsr score  \
# 1259               Hungary       3.1    501+       3.6    501+        2.0
# ...

# %% [markdown]
# # Australian universities

# %%
data_a = data[(data['location'] == 'Australia')]
data_a
# Out:
#       Rank                                        institution location code  \
# 29      30                 The Australian National University            AU
# 32      33                        The University of Melbourne            AU
# 40      41                           The University of Sydney            AU
# 44      45    The University of New South Wales (UNSW Sydney)            AU
# 50      51                       The University of Queensland            AU
# 56      57                                  Monash University            AU
# 89      90                The University of Western Australia            AU
# 108    109                         The University of Adelaide            AU
# 136    137                    University of Technology Sydney            AU
# 186    187                           University of Wollongong            AU
# 189    190                                    RMIT University            AU
# ...

# %%
data.loc[data.location.isin(["Australia"])]
# Out:
#       Rank                                        institution location code  \
# 29      30                 The Australian National University            AU
# 32      33                        The University of Melbourne            AU
# 40      41                           The University of Sydney            AU
# 44      45    The University of New South Wales (UNSW Sydney)            AU
# 50      51                       The University of Queensland            AU
# 56      57                                  Monash University            AU
# 89      90                The University of Western Australia            AU
# 108    109                         The University of Adelaide            AU
# 136    137                    University of Technology Sydney            AU
# 186    187                           University of Wollongong            AU
# 189    190                                    RMIT University            AU
# ...

# %%
data_a.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11180\759875976.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_a.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
#                                                                   ger rank  \
#                                                                      count
# Rank institution                                        location
# 30   The Australian National University                 Australia        1
# 33   The University of Melbourne                        Australia        1
# 41   The University of Sydney                           Australia        1
# 45   The University of New South Wales (UNSW Sydney)    Australia        1
# 51   The University of Queensland                       Australia        1
# 57   Monash University                                  Australia        1
# ...

# %%
data_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 29 to 1290
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           38 non-null     int64
#  1   institution    38 non-null     object
#  2   location code  38 non-null     object
#  3   location       38 non-null     object
#  4   ar score       38 non-null     float64
#  5   ar rank        38 non-null     object
#  6   er score       38 non-null     float64
#  7   er rank        38 non-null     object
#  8   fsr score      38 non-null     float64
#  9   fsr rank       38 non-null     object
#  10  cpf score      38 non-null     float64
#  11  cpf rank       38 non-null     object
#  12  ifr score      38 non-null     float64
#  13  ifr rank       38 non-null     object
#  14  isr score      38 non-null     float64
#  15  isr rank       38 non-null     object
#  16  irn score      38 non-null     float64
# ...

# %%
plt.figure(figsize=(40, 20))
x = data_a['institution']
y = data_a['Rank']
plt.hist(x, bins=30, color='red', edgecolor='black',
         linestyle='--', alpha=0.5)
 
# Adding title to the plot
plt.title("Uni Ranking")
 
# Adding label on the y-axis
plt.ylabel('Ranking')
 
# Adding label on the x-axis
plt.xlabel('Universities')
 
plt.show()

# %%
data_a.head()
# Out:
#     Rank                                      institution location code  \
# 29    30               The Australian National University            AU
# 32    33                      The University of Melbourne            AU
# 40    41                         The University of Sydney            AU
# 44    45  The University of New South Wales (UNSW Sydney)            AU
# 50    51                     The University of Queensland            AU
#
#      location  ar score ar rank  er score er rank  fsr score fsr rank  ...  \
# 29  Australia      93.6      35      70.1      95       38.0      404  ...
# 32  Australia      98.6      20      94.9      34       17.9     601+  ...
# 40  Australia      96.2      30      91.7      49       15.6     601+  ...
# 44  Australia      89.0      46      91.1      53       16.8     601+  ...
# 50  Australia      86.6      52      75.6      83       20.2     601+  ...
#
#     cpf rank ifr score  ifr rank isr score  isr rank irn score  irn rank  \
# ...

# %%
data_a.describe()
# Out:
#               Rank   ar score   er score  fsr score  cpf score   ifr score  \
# count    38.000000  38.000000  38.000000  38.000000  38.000000   38.000000
# mean    416.157895  30.421053  29.986842  12.378947  59.173684   80.973684
# std     328.863689  30.235089  28.852347  10.104753  29.888158   29.125726
# min      30.000000   2.600000   2.900000   1.700000   7.400000    3.200000
# 25%     187.750000   7.450000   7.500000   5.025000  35.025000   73.650000
# 50%     308.500000  18.650000  16.500000   9.050000  64.200000   94.650000
# 75%     647.500000  38.775000  46.975000  17.100000  87.750000   99.900000
# max    1291.000000  98.600000  94.900000  45.800000  99.300000  100.000000
#
#         isr score  irn score  ger score
# count   38.000000  38.000000  38.000000
# mean    72.984211  74.239474  27.918421
# std     30.522057  23.194519  25.776785
# min      1.500000  15.300000   2.900000
# 25%     51.200000  59.075000   7.450000
# 50%     87.400000  82.550000  19.600000
# ...

# %%
plt.figure(figsize=(30, 20))
x = data_a['Rank']
y = np.vstack([data_a['institution'], 
                   data_a['ger rank'], 
                      data_a['score scaled']])

labels = ['institution', 'ger rank', 'scaled score']

colors = ['sandybrown', 'tomato', 'skyblue']

plt.stackplot(x,y, labels = labels,
             colors = colors)
 
plt.legend(loc=2)
 
plt.show()

# %%
plt.figure(figsize=(25, 17))
sns.set()
sns.barplot(data_a['Rank'], data_a['institution'])
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rank', ylabel='institution'>

# %% [markdown]
# # Canada universities

# %%
data_c = data[(data['location'] == 'Canada')]
data_c
# Out:
#       Rank                              institution location code location  \
# 30      31                        McGill University            CA   Canada
# 34      35                    University of Toronto            CA   Canada
# 46      47           University of British Columbia            CA   Canada
# 109    110                    University of Alberta            CA   Canada
# 116    117                  Université de Montréal             CA   Canada
# 151    152                      McMaster University            CA   Canada
# 153    154                   University of Waterloo            CA   Canada
# 172    173                       Western University            CA   Canada
# 238    239                     University of Ottawa            CA   Canada
# 241    242                    University of Calgary            CA   Canada
# 245    246           Queen's University at Kingston            CA   Canada
# ...

# %%
data_c.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11180\2810518442.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_c.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
#                                                       ger rank               \
#                                                          count unique   top
# Rank institution                             location
# 31   McGill University                       Canada          1      1    72
# 35   University of Toronto                   Canada          1      1    45
# 47   University of British Columbia          Canada          1      1   119
# 110  University of Alberta                   Canada          1      1   318
# 117  Université de Montréal                  Canada          1      1  601+
# 152  McMaster University                     Canada          1      1   301
# ...

# %%
data_c.describe()
# Out:
#               Rank   ar score   er score  fsr score  cpf score   ifr score  \
# count    31.000000  31.000000  31.000000  31.000000  29.000000   26.000000
# mean    508.064516  27.158065  33.848387  22.058065  43.058621   69.673077
# std     371.348258  27.617118  28.260312  25.084866  21.437209   28.519573
# min      31.000000   2.800000   4.200000   1.700000  11.000000    2.400000
# 25%     206.000000   6.400000  11.900000   3.850000  27.600000   53.350000
# 50%     456.000000  18.500000  21.200000   7.000000  42.100000   79.800000
# 75%     756.000000  37.350000  49.550000  30.900000  53.900000   91.025000
# max    1386.000000  99.600000  98.300000  84.700000  96.900000  100.000000
#
#        isr score  irn score  ger score
# count  29.000000  29.000000  31.000000
# mean   53.696552  74.510345  32.948387
# std    27.259762  17.508495  28.249081
# min     4.100000  32.900000   3.900000
# 25%    33.200000  63.800000  11.800000
# 50%    54.200000  77.600000  20.100000
# ...

# %%
plt.figure(figsize=(25, 17))
sns.set()
sns.barplot(data_c['Rank'], data_c['institution'])
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rank', ylabel='institution'>

# %% [markdown]
# # United kingdom

# %%
data.loc[data.location.isin(["United Kingdom"])]
# Out:
#       Rank                    institution location code        location  \
# 1        2        University of Cambridge            UK  United Kingdom
# 3        4           University of Oxford            UK  United Kingdom
# 6        7        Imperial College London            UK  United Kingdom
# 7        8                            UCL            UK  United Kingdom
# 14      15    The University of Edinburgh            UK  United Kingdom
# ...    ...                            ...           ...             ...
# 1066  1067       Leeds Beckett University            UK  United Kingdom
# 1092  1093    Sheffield Hallam University            UK  United Kingdom
# 1108  1109  The University of Northampton            UK  United Kingdom
# 1163  1164            University of Derby            UK  United Kingdom
# 1194  1195    University of Wolverhampton            UK  United Kingdom
#
#       ar score ar rank  er score er rank  fsr score fsr rank  ...  cpf rank  \
# ...

# %%
data_u = data[(data['location'] == 'United Kingdom')]
data_u
# Out:
#       Rank                    institution location code        location  \
# 1        2        University of Cambridge            UK  United Kingdom
# 3        4           University of Oxford            UK  United Kingdom
# 6        7        Imperial College London            UK  United Kingdom
# 7        8                            UCL            UK  United Kingdom
# 14      15    The University of Edinburgh            UK  United Kingdom
# ...    ...                            ...           ...             ...
# 1066  1067       Leeds Beckett University            UK  United Kingdom
# 1092  1093    Sheffield Hallam University            UK  United Kingdom
# 1108  1109  The University of Northampton            UK  United Kingdom
# 1163  1164            University of Derby            UK  United Kingdom
# 1194  1195    University of Wolverhampton            UK  United Kingdom
#
#       ar score ar rank  er score er rank  fsr score fsr rank  ...  cpf rank  \
# ...

# %%
data_u.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5644\2504288087.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data_u.groupby(['Rank', 'institution', 'location'])['ger rank', 'score scaled'].describe()
#                                                   ger rank                    \
#                                                      count unique   top freq
# Rank institution                   location
# 2    University of Cambridge       United Kingdom        1      1     9    1
# 4    University of Oxford          United Kingdom        1      1     7    1
# 7    Imperial College London       United Kingdom        1      1    76    1
# 8    UCL                           United Kingdom        1      1    71    1
# 15   The University of Edinburgh   United Kingdom        1      1   219    1
# ...                                                    ...    ...   ...  ...
# ...

# %%
data_u.head(10)
# Out:
#     Rank                                        institution location code  \
# 1      2                            University of Cambridge            UK
# 3      4                               University of Oxford            UK
# 6      7                            Imperial College London            UK
# 7      8                                                UCL            UK
# 14    15                        The University of Edinburgh            UK
# 27    28                       The University of Manchester            UK
# 36    37                              King's College London            UK
# 55    56  The London School of Economics and Political S...            UK
# 61    62                              University of Bristol            UK
# 63    64                          The University of Warwick            UK
#
#           location  ar score ar rank  er score er rank  fsr score fsr rank  \
# 1   United Kingdom     100.0       2     100.0       2      100.0       11
# ...

# %%
plt.figure(figsize=(35, 40))
sns.set()
sns.barplot(data_u['Rank'], data_u['institution'])
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rank', ylabel='institution'>
